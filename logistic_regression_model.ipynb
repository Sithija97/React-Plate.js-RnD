# %% [markdown]
# <a href="https://colab.research.google.com/github/Sithija97/Python-Projects/blob/main/logistic_regression_model.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # logistic_regression_model
#
# a model we try to experiment the cricket shot classification with shot errors

# %%
import pandas as pd
from matplotlib import pyplot as plt
# %matplotlib inline

# %%
from google.colab import files

uploaded = files.upload()
# Out:
#      <input type="file" id="files-ccb79977-c359-4d8c-9a6e-2412372b8b8f" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-ccb79977-c359-4d8c-9a6e-2412372b8b8f">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving shot_details.csv to shot_details (1).csv

# %%
# reading the csv file
df = pd.read_csv("shot_details.csv")
df.head()
# Out:
#   fv.st.hp   fv.st.ba   fv.st.tha  ... sv.ft.hip.a            shot name  accuracy
# 0        0  31.916175  173.797075  ...  177.717712  front foot deffence       0.0
# 1        1  35.921699  172.392522  ...  191.555889  front foot deffence       1.0
# 2        1  17.407319  186.705333  ...  193.097152  front foot deffence       1.0
# 3        1  11.201362  170.778109  ...  245.867717                 pull       0.0
# 4        1   0.017454  173.508956  ...  245.867717                 pull       0.0
#
# [5 rows x 58 columns]

# %%
# data exploration and visualization - can be used to seperate left/right handed || technically correct/wrong shots
left = df[df.accuracy==1]
left.shape
left.head()
# Out:
#   fv.st.hp   fv.st.ba   fv.st.tha  ... sv.ft.hip.a            shot name  accuracy
# 1        1  35.921699  172.392522  ...  191.555889  front foot deffence       1.0
# 2        1  17.407319  186.705333  ...  193.097152  front foot deffence       1.0
# 5        1  15.190306  179.006391  ...  136.429447                 pull       1.0
# 6        1  28.749740  173.949000  ...  167.264520                 pull       1.0
# 7        1  28.749740  173.949000  ...  167.264520                 pull       1.0
#
# [5 rows x 58 columns]

# %%
# average numbers for all columns
df.groupby('accuracy').mean()
# Out:
#            fv.st.ba   fv.st.tha  ...  sv.ft.bf.ka  sv.ft.hip.a
# accuracy                         ...
# 0.0       14.378330  172.694713  ...   151.930677   223.151049
# 1.0       26.990084  176.399128  ...   180.215790   169.614694
#
# [2 rows x 54 columns]

# %%
# determining independant variables
# subdf = df[['','','','']]
# subdf.head()

# %%
# split the dataset into train and test subsets
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(df[['','','','']],df.accuracy,train_size=0.3)

# %%
# import the model
from sklearn.linear_model import LogisticRegression
model = LogisticRegression()

# %%
# training the model
model.fit(X_train, y_train)

# %%
# predicting the outputs
model.predict(X_test)

# %%
# accuracy of the model
model.score(X_test,y_test)
